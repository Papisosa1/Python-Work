# %%
import os
os.getcwd()
# Out:
# '/Users/esosaedogiawerie'

# %%
os.chdir('/users/')
os.getcwd()
# Out:
# '/Users'

# %%
os.listdir('/Users/esosaedogiawerie')
# Out:
# ['Assignment on Numpy.ipynb',
#  'assignment on panda.ipynb',
#  '.config',
#  'Music',
#  '.condarc',
#  '.DS_Store',
#  '.CFUserTextEncoding',
#  '.xonshrc',
#  '.zshrc',
#  'Pictures',
#  'CSV FILE .ipynb',
#  'Python beginner lectures  (1).ipynb',
#  'Dictionary.ipynb',
#  '.zsh_history',
#  '.ipython',
#  'Desktop',
#  'Library',
#  'Parallels',
#  'Zotero',
#  '.cups',
#  'Public',
#  '.tcshrc',
#  '.anaconda',
#  'Applications (Parallels)',
#  'Movies',
#  'Applications',
#  'opt',
#  '.Trash',
#  'Resignation Letter.pdf',
#  '.ipynb_checkpoints',
#  '.jupyter',
#  'Documents',
#  '.anydesk',
#  'Assignment.ipynb',
#  '.vscode',
#  '.bash_profile',
#  'List Comprehention.ipynb',
#  'Downloads',
#  '.python_history',
#  '.continuum',
#  'OneDrive - Coventry University',
#  '.zsh_sessions',
#  '.conda',
#  'practise.ipynb']

# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# '/Users'

# %%
df=pd.read_csv('/Users/esosaedogiawerie/Documents/Data Analysis/titanic (1).csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
print(df['Name'])
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
condition = df['Age'] > 30
print(condition)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Cabin'].describe()
# Out:
# count         204
# unique        147
# top       B96 B98
# freq            4
# Name: Cabin, dtype: object

# %%
df['Ticket'].describe()
# Out:
# count        891
# unique       681
# top       347082
# freq           7
# Name: Ticket, dtype: object

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Name'].describe()
# Out:
# count                         891
# unique                        891
# top       Braund, Mr. Owen Harris
# freq                            1
# Name: Name, dtype: object

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
youngest_child=df[df['Age']==0.42]
youngest_child
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %%
# Find the oldest person in the ship
oldest=df['Age'].max()
oldest
oldest=df.loc[df['Age'].idxmax()]
print(oldest)
# Out:
# PassengerId                                     631
# Survived                                          1
# Pclass                                            1
# Name           Barkworth, Mr. Algernon Henry Wilson
# Sex                                            male
# Age                                            80.0
# SibSp                                             0
# Parch                                             0
# Ticket                                        27042
# Fare                                           30.0
# Cabin                                           A23
# Embarked                                          S
# Name: 630, dtype: object

# %%
pclass=df['Pclass'].value_counts()
pclass
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
first_class=df[df['Pclass']==1]
first_class
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
second_class=df[df['Pclass']==2]
second_class
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 17                   Williams, Mr. Charles Eugene    male   NaN      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# 21                          Beesley, Mr. Lawrence    male  34.0      0      0
# ...

# %%
third_class=df[df['Pclass']==3]
third_class
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
survived_count=df[df['Survived']==1]
survived_count
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
death_count=df[df['Survived']==0]
death_count
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
survived_count=df['Survived'].sum()
death_count=len(df) - survived_count

print(survived_count)
print(death_count)
# Out:
# 342
# 549

# %%
# Define the name of the person you're looking for
person_name = "Montvila, Rev. Juozas"

# Filter the dataset to find the specific person
person_info = df[df['Name'] == person_name]

print(person_info)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 886          887         0       2  Montvila, Rev. Juozas  male  27.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 886      0  211536  13.0   NaN        S

# %%
# Define the name of the person you're looking for
person_name = "Behr, Mr. Karl Howell"

# Filter the dataset to find the specific person
person_info = df[df['Name'] == person_name]

print(person_info)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 889      0  111369  30.0  C148        C

# %%
# Define the name of the person you're looking for
person_name = "Thomas, Master. Assad Alexander"

# Filter the dataset to find the specific person
person_info = df[df['Name'] == person_name]

print(person_info)
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %%
# Define the name of the person you're looking for
person_name = "Eva Hart"

# Filter the dataset to find the specific person
person_info = df[df['Name'] == person_name]

if not person_info.empty:
    print("Information about Eva Hart:")
    print(person_info)
else:
    print("Eva Hart not found in the dataset.")
# Out:
# Eva Hart not found in the dataset.

# %%
# Define the name of the person you're looking for
person_name = "Elsie Bowerman"

# Filter the dataset to find the specific person
person_info = df[df['Name'] == person_name]

if not person_info.empty:
    print("Information about Elsie Bowerman:")
    print(person_info)
else:
    print("Elsie Bowerman not found in the dataset.")
# Out:
# Elsie Bowerman not found in the dataset.

# %%
# Calculate the total number of passengers
total_passengers = len(df)

# Calculate the total number of survivors
total_survivors = df['Survived'].sum()

# Calculate the overall survival rate
survival_rate = total_survivors / total_passengers

# Calculate the percentage of passengers who survived
survival_percentage = survival_rate * 100

print(survival_percentage)
# Out:
# 38.38383838383838

# %%
# Calculate the number of survivors in each class
survivors_by_class = df.groupby('Pclass')['Survived'].sum()

print(survivors_by_class)
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
passengers_by_class = df['Pclass'].value_counts()
survival_rate_by_class = survivors_by_class / passengers_by_class
survival_rate_by_class
# Out:
# 1    0.629630
# 2    0.472826
# 3    0.242363
# dtype: float64

# %%
# Calculate the total number of passengers for each gender
passengers_by_gender = df['Sex'].value_counts()

# Calculate the number of survivors for each gender
survivors_by_gender = df.groupby('Sex')['Survived'].sum()

# Calculate the survival rate for each gender
survival_rate_by_gender = survivors_by_gender / passengers_by_gender
survival_rate_by_gender
# Out:
# female    0.742038
# male      0.188908
# dtype: float64
